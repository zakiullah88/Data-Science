# %% [markdown]
# # Pandas More Utility Functions
#
# A demonstration of advanced `pandas` syntax to accompany Lecture 4.

# %%
from google.colab import drive
drive.mount('/content/drive')

#df = pd.read_csv('/content/drive/My Drive/Data for Pandas/babynamesbystate/STATE.CA.txt')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import plotly.express as px

# %% [markdown]
# ## Dataset: California baby names
#
# In today's lecture, we'll work with the `babynames` dataset, which contains information about the names of infants born in California.
#
# The cell below pulls census data from a government website and then loads it into a usable form. The code shown here is outside of the scope of Data 100, but you're encouraged to dig into it if you are interested!

# %%
import urllib.request
import os.path
import zipfile

data_url = "https://www.ssa.gov/oact/babynames/state/namesbystate.zip"
local_filename = "babynamesbystate.zip"
if not os.path.exists(local_filename): # If the data exists don't download again
    with urllib.request.urlopen(data_url) as resp, open(local_filename, 'wb') as f:
        f.write(resp.read())

zf = zipfile.ZipFile(local_filename, 'r')

ca_name = 'CA.TXT'
field_names = ['State', 'Sex', 'Year', 'Name', 'Count']
with zf.open(ca_name) as fh:
    babynames = pd.read_csv(fh, header=None, names=field_names)

babynames.head()
# Out:
#   State Sex  Year      Name  Count
# 0    CA   F  1910      Mary    295
# 1    CA   F  1910     Helen    239
# 2    CA   F  1910   Dorothy    220
# 3    CA   F  1910  Margaret    163
# 4    CA   F  1910   Frances    134

# %% [markdown]
# ### Exercises
# We want to obtain the first three baby names with `count > 250`.
#
# 1.Code this using head()
#
# 2.Code this using loc
#
# 3.Code this using iloc
#
# 4.Code this using []

# %%
# Answer Here
# Out:
#     State Sex  Year  Name  Count
# 0      CA   F  1910  Mary    295
# 233    CA   F  1911  Mary    390
# 484    CA   F  1912  Mary    534

# %%
# Answer Here
# Out:
#     State Sex  Year  Name  Count
# 0      CA   F  1910  Mary    295
# 233    CA   F  1911  Mary    390
# 484    CA   F  1912  Mary    534

# %%
# Answer Here
# Out:
#     State Sex  Year  Name  Count
# 0      CA   F  1910  Mary    295
# 233    CA   F  1911  Mary    390
# 484    CA   F  1912  Mary    534

# %%
# Answer Here
# Out:
#     State Sex  Year  Name  Count
# 0      CA   F  1910  Mary    295
# 233    CA   F  1911  Mary    390
# 484    CA   F  1912  Mary    534

# %% [markdown]
# ### `.isin` for Selection based on a list, array, or `Series`

# %%
# Note: The parentheses surrounding the code make it possible to break the code into multiple lines for readability
babynames[(babynames["Name"] == "Bella") |
              (babynames["Name"] == "Alex") |
              (babynames["Name"] == "Narges") |
              (babynames["Name"] == "Lisa")]
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %%
# A more concise method to achieve the above: .isin
#Answer Here
# Out:
#        State Sex  Year   Name  Count
# 6289      CA   F  1923  Bella      5
# 7512      CA   F  1925  Bella      8
# 12368     CA   F  1932   Lisa      5
# 14741     CA   F  1936   Lisa      8
# 17084     CA   F  1939   Lisa      5
# ...      ...  ..   ...    ...    ...
# 399773    CA   M  2019   Alex    438
# 402648    CA   M  2020   Alex    379
# 405452    CA   M  2021   Alex    334
# 408335    CA   M  2022   Alex    345
# 411228    CA   M  2023   Alex    329
#
# [321 rows x 5 columns]

# %% [markdown]
# ### `.str` Functions for Defining a Condition

# %%
# What if we only want names that start with "J"?
#Answer Here
# Out:
#        State Sex  Year       Name  Count
# 16        CA   F  1910  Josephine     66
# 44        CA   F  1910       Jean     35
# 46        CA   F  1910     Jessie     32
# 59        CA   F  1910      Julia     28
# 66        CA   F  1910    Juanita     25
# ...      ...  ..   ...        ...    ...
# 413714    CA   M  2023         Jj      5
# 413715    CA   M  2023  Johnathon      5
# 413716    CA   M  2023     Jorden      5
# 413717    CA   M  2023      Jozef      5
# 413718    CA   M  2023    Juliano      5
#
# [35170 rows x 5 columns]

# %% [markdown]
# # Custom Sort

# %%
# Sort a Series Containing Names
# Out:
# 387660      Aadan
# 369654      Aadan
# 372774      Aadan
# 401876    Aadarsh
# 388799      Aaden
#            ...
# 232190      Zyrah
# 220708      Zyrah
# 217445      Zyrah
# 197542      Zyrah
# 408216      Zyrus
# Name: Name, Length: 413894, dtype: object

# %%
# Sort a DataFrame – there are lots of Michaels in California
# Out:
#        State Sex  Year           Name  Count
# 271693    CA   M  1957        Michael   8263
# 270669    CA   M  1956        Michael   8257
# 321036    CA   M  1990        Michael   8247
# 285500    CA   M  1969        Michael   8244
# 286795    CA   M  1970        Michael   8197
# ...      ...  ..   ...            ...    ...
# 294982    CA   M  1975  Michaelangelo      5
# 294981    CA   M  1975          Micha      5
# 294980    CA   M  1975         Markus      5
# 294979    CA   M  1975   Marcoantonio      5
# 413893    CA   M  2023           Zyir      5
#
# [413894 rows x 5 columns]

# %% [markdown]
# ### Approach 1: Create a temporary column

# %%
# Create a Series of the length of each name
babynames['name_length'] = babynames['Name'].apply(len)
# Add the Series as a new column to the DataFrame
babynames_sorted = babynames.sort_values(by='name_length')
# Sort the DataFrame by the new column
babynames_sorted
# Out:
#        State Sex  Year             Name  Count  name_length
# 83016     CA   F  1979               Ji      5            2
# 331174    CA   M  1993               Vu      5            2
# 298821    CA   M  1978               Al     13            2
# 277555    CA   M  1962               Ty     55            2
# 404824    CA   M  2020               Jj      6            2
# ...      ...  ..   ...              ...    ...          ...
# 337819    CA   M  1996  Franciscojavier      8           15
# 325562    CA   M  1991  Franciscojavier      6           15
# 316193    CA   M  1987  Franciscojavier      5           15
# 317627    CA   M  1988  Franciscojavier     10           15
# 102512    CA   F  1986  Mariadelosangel      5           15
#
# [413894 rows x 6 columns]

# %%
# drop new column
babynames = babynames.drop("name_length", axis = "columns")

# %% [markdown]
# ### Approach 2: Sorting using the `key` argument
#
# ---

# %%
# Answer Here
# Out:
#        State Sex  Year             Name  Count
# 83016     CA   F  1979               Ji      5
# 331174    CA   M  1993               Vu      5
# 298821    CA   M  1978               Al     13
# 277555    CA   M  1962               Ty     55
# 404824    CA   M  2020               Jj      6
# ...      ...  ..   ...              ...    ...
# 337819    CA   M  1996  Franciscojavier      8
# 325562    CA   M  1991  Franciscojavier      6
# 316193    CA   M  1987  Franciscojavier      5
# 317627    CA   M  1988  Franciscojavier     10
# 102512    CA   F  1986  Mariadelosangel      5
#
# [413894 rows x 5 columns]

# %% [markdown]
# ### Approach 3: Sorting Using the `map` Function
#
# We can also use the Python map function if we want to use an arbitrarily defined function. Suppose we want to sort by the number of occurrences of "dr" plus the number of occurences of "ea".

# %%
# Define a function to count occurrences of 'dr' and 'ea'
def count_substrings(name):
    count_dr = name.lower().count('dr')
    count_ea = name.lower().count('ea')
    return count_dr + count_ea

# Apply the function to the 'Name' column and create a new column 'Count'
babynames['Count'] = babynames['Name'].apply(count_substrings)

# Sort the DataFrame by the 'Count' column in descending order
babynames_sorted = babynames.sort_values(by='Count', ascending=False)

# Display the top rows
print(babynames_sorted.head())
# Out:
#        State Sex  Year      Name  Count
# 108738    CA   F  1988  Deandrea      3
# 115965    CA   F  1990  Deandrea      3
# 311780    CA   M  1985  Deandrea      3
# 131037    CA   F  1994  Leandrea      3
# 101982    CA   F  1986  Deandrea      3

# %%
# Drop the `dr_ea_count` column
babynames = babynames.drop("Count", axis = "columns")

# %% [markdown]
# ## Grouping
#
# Group rows that share a common feature, then aggregate data across the group.
#
# In this example, we count the total number of babies born in each year (considering only a small subset of the data, for simplicity).
#
# <img src="images/groupby.png" width="800"/>

# %%
# DataFrame with baby gril names only


# Answer Here
#Groupby similar features like year and apply aggregate

# Answer Here
# Sort by Count
# Sort by Count in descending order

# Answer Here
# Out:
#     Year   Count
# 80  1990  262422
# 81  1991  261497
# 82  1992  256788
# 83  1993  249572
# 79  1989  243985
# ..   ...     ...
# 4   1914   13815
# 3   1913   11860
# 2   1912    9804
# 1   1911    6602
# 0   1910    5950
#
# [114 rows x 2 columns]

# %%
# print first 10 entries

# %%
# the total baby count in each year
# Answer Here

# %% [markdown]
# There are many different aggregation functions we can use, all of which are useful in different applications.

# %%
# What is the earliest year in which each name appeared?
# Answer Here

# %%
# What is the largest single-year count of each name?
# Answer Here

# %%
#Can you find the most popular baby name in the state of California (CA) for each year? use idxmax function.
#Provide a list of years along with the corresponding most popular names."
result = babynames.groupby("Year")['Count'].idxmax()
#Answer Here

# %% [markdown]
# ## Case Study: Name "Popularity"

# %% [markdown]
# In this exercise, let's find the name with sex "F" that has dropped most in popularity since its peak usage. We'll start by filtering `babynames` to only include names corresponding to sex "F".

# %%
#Answer Here
female_babynames = babynames[babynames["Sex"] == "F"]
female_babynames = female_babynames.sort_values("Year")

max_female_baby_names = max(female_babynames[female_babynames["Name"] == "Jennifer"]["Count"])

curr_female_baby_names = female_babynames[female_babynames["Name"] == "Jennifer"]["Count"].iloc[-1]

rtp = curr_female_baby_names / max_female_baby_names

def ratio_to_peak(series):
  return series.iloc[-1] / max(series)

grouped = female_babynames.groupby("Name")["Count"]

result = grouped.apply(ratio_to_peak)

rtp_table = female_babynames.groupby("Name")[["Year","Count"]].agg(ratio_to_peak)

rtp_table = female_babynames.groupby("Name")[["Count"]].agg(ratio_to_peak)

rtp_table = rtp_table.rename(columns = {"Count": "Count RTP"})

rtp_table

rtp_table.sort_values("Count RTP")

print(rtp_table)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Count'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c89b5091fe3b> in <cell line: 5>()
#       3 female_babynames = female_babynames.sort_values("Year")
#       4
# ----> 5 max_female_baby_names = max(female_babynames[female_babynames["Name"] == "Jennifer"]["Count"])
#       6
#       7 curr_female_baby_names = female_babynames[female_babynames["Name"] == "Jennifer"]["Count"].iloc[-1]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Count'

# %%
# We sort the data by year
babynames["Year"].sort_values()
# Out:
# 0         1910
# 243306    1910
# 243307    1910
# 243308    1910
# 243309    1910
#           ...
# 240783    2023
# 240784    2023
# 240785    2023
# 240759    2023
# 413893    2023
# Name: Year, Length: 413894, dtype: int64

# %% [markdown]
# To build our intuition on how to answer our research question, let's visualize the prevalence of the name "Jennifer" over time.

# %%
# We'll talk about how to generate plots in a later lecture
fig = px.line(female_babynames[female_babynames["Name"] == "Jennifer"],
              x = "Year", y = "Count")
fig.update_layout(font_size = 18,
                  autosize=False,
                 width=500,
                  height=200)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="56b49769-39e1-4ca6-9d33-2e5117b1363e" class="plotly-graph-div" style="height:200px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56b49769-39e1-4ca6-9d33-2e5117b1363e")) {                    Plotly.newPlot(                        "56b49769-39e1-4ca6-9d33-2e5117b1363e",                        [{"hovertemplate":"Year=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1934,1938,1939,1940,1941,1942,1943,1944,1945,1946,1947,1948,1949,1950,1951,1952,1953,1954,1955,1956,1957,1958,1959,1960,1961,1962,1963,1964,1965,1966,1967,1968,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,1954,1961,1965,1967,1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979,1980,1981,1982,1983,1984,1985,1986,1987,1988,1989,1990,1991,1992,1993,1994,1995,1996,1997,1998,1999,2000,2001,2002],"xaxis":"x","y":[5,5,6,13,24,22,30,80,99,147,163,159,233,247,284,350,384,412,440,509,635,739,707,869,1174,1256,1385,1516,1649,1919,1902,2908,3477,4696,5456,6065,5649,5673,5323,5569,5543,5295,5461,5612,5628,5813,5831,5521,4965,4306,4285,3875,3529,3610,3579,3382,3003,2940,2696,2529,2817,2561,2675,2265,2027,1987,1699,1485,1297,1144,1035,808,641,515,474,421,354,286,243,239,226,168,145,141,91,115,88,5,8,5,5,9,11,20,16,19,16,19,13,15,24,9,25,18,18,29,27,18,19,23,22,29,27,30,24,24,17,23,18,15,10,12,10,8,7],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"] ...

# %% [markdown]
# We'll need a mathematical definition for the change in popularity of a name.
#
# Define the metric "ratio to peak" (RTP). We'll calculate this as the count of the name in 2022 (the most recent year for which we have data) divided by the largest count of this name in *any* year.
#
# A demo calculation for Jennifer:

# %%
# Find the highest Jennifer 'count'
max_jenn = max(babynames[babynames["Name"] == "Jennifer"]["Count"])

# %%
# Remember that we sorted f_babynames by year.
# This means that grabbing the final entry gives us the most recent count of Jennifers: 114
# In 2022, the most recent year for which we have data, 114 Jennifers were born
curr_jenn = babynames[babynames["Name"] == "Jennifer"]["Count"].iloc[-1]

# %%
# Compute the RTP
rtp = curr_jenn / max_jenn

# %% [markdown]
# We can also write a function that produces the `ratio_to_peak`for a given `Series`. This will allow us to use `.groupby` to speed up our computation for all names in the dataset.

# %%
# define the function for RTP
"""
Compute the RTP for a Series containing the counts per year for a single name
"""
def ratio_to_peak(series):
    return series.iloc[-1] / max(series)

# %%
# Construct a Series containing our Jennifer count data
# Then, find the RTP using the function define above
jenn_counts_ser = babynames[babynames["Name"] == "Jennifer"]["Count"]
ratio_to_peak(jenn_counts_ser)
# Out:
# 0.0011541632316570487

# %% [markdown]
# Now, let's use `.groupby` to compute the RTPs for *all* names in the dataset.
#
# You may see a warning message when running the cell below. As discussed in lecture, `pandas` can't apply an aggregation function to non-numeric data (it doens't make sense to divide "CA" by a number). By default, `.groupby` will drop any columns that cannot be aggregated.

# %%
# Results in a TypeError
#rtp_table = f_babynames.groupby("Name").agg(ratio_to_peak)
#rtp_table
rtp_table = babynames.groupby("Name")[["Year","Count"]].agg(ratio_to_peak)

# %%
# Find the RTP fro all names at once using groupby as describe in lec slides
rtp_table = (
  babynames.groupby("Name")[["Year","Count"]].agg(ratio_to_peak)
  )

# %% [markdown]
# To avoid the warning message above, we explicitly extract only the columns relevant to our analysis before using `.agg`.

# %%
# Recompute the RTPs, but only performing the calculation on the "Count" column

# %%
# Rename "Count" to "Count RTP" for clarity

# %%
# What name has fallen the most in popularity?
most_fallen_name = rtp_table[0]
print("The name that has fallen the most in popularity is: ", most_fallen_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-45c278dcefc5> in <cell line: 2>()
#       1 # What name has fallen the most in popularity?
# ----> 2 most_fallen_name = rtp_table[0]
#       3 print(f"The name that has fallen the most in popularity is: {most_fallen_name}")
#
# NameError: name 'rtp_table' is not defined

# %% [markdown]
# We can visualize the decrease in the popularity of the name "?:"

# %%
def plot_name(*names):
    fig = px.line(female_babynames[female_babynames["Name"].isin(names)],
                  x = "Year", y = "Count", color="Name",
                  title=f"Popularity for: {names}")
    fig.update_layout(font_size = 18,
                  autosize=False,
                  width=1000,
                  height=400)
    return fig
# pass the name into plot_name
plot_name("-")

# %%
# Find the 10 names that have decreased the most in popularity
# Answer Here

top10 = rtp_table.sort_values("Count RTP").head(10).index
px.line(female_babynames[female_babynames["Name"].isin(top10)],
x = "Year", y = "Count", color = "Name")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-eef626b37296> in <cell line: 4>()
#       2 # Answer Here
#       3
# ----> 4 top10 = rtp_table.sort_values("Count RTP").head(10).index
#       5 px.line(female_babynames[female_babynames["Name"].isin(top10)],
#       6 x = "Year", y = "Count", color = "Name")
#
# NameError: name 'rtp_table' is not defined

# %%
plot_name(*top10)

# %% [markdown]
# For fun, try plotting your name or your friends' names.
